# %% [markdown]
# <a href="https://colab.research.google.com/github/Err0r789/Youtube-transcript-summarizer/blob/main/Summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
# !pip install -q youtube_transcript_api

# %%
# !pip install summa

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video = "https://www.youtube.com/watch?v=6uUblznfrsk"

# %%
video_id = youtube_video.split("=")[1]

# %%
video_id
# Out:
# '6uUblznfrsk'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': "if everyone's problems were like laundry",
#   'start': 0.08,
#   'duration': 6.48},
#  {'text': 'hanging out to dry in an open field and',
#   'start': 4.359,
#   'duration': 4.881},
#  {'text': 'you had the opportunity to go out into',
#   'start': 6.56,
#   'duration': 5.72},
#  {'text': 'that field and exchange your laundry',
#   'start': 9.24,
#   'duration': 5.12},
#  {'text': 'your problems in other words with anyone',
#   'start': 12.28,
#   'duration': 7.079}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 13120

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  out = summarizer(result[start:end], min_length =5, max_length =20)
  out = out[0]
  out = out['summary_text']
  summarized_text.append(out)

text1 = summarized_text

print(summarized_text)
# Out:
# [" If everyone's problems were like laundry hanging out to dry in an open field and you", ' The world as we see it today we are wrestling with climate change pandemics terrorism', ' Through the metaverse we can live not just a virtual second life but also a parallel', ' Your generation will have to Grapple with portentous issues that your generation will', ' Mahendr says to embrace the ought not the is shape the world as it ought', ' Mahendra was founded by Two Brothers around the time of Independence it was a time', ' In the early 90s India and Indian industry were both in crisis faced with the prospect', ' He Future kind of situation where once again we had to prove that we as an Indian', ' Between 2002 and 2013 our profits went up 33 times our stock price went up 72 times', " Fletcher says it's important to accept that purpose can evolve and it can transform . He", " Taxi driver said everyone's problems are like laundry hanging out to dry in an open field", " I ask you why can't t
# ...

# %%
print(text1)
# Out:
# [" If everyone's problems were like laundry hanging out to dry in an open field and you", ' The world as we see it today we are wrestling with climate change pandemics terrorism', ' Through the metaverse we can live not just a virtual second life but also a parallel', ' Your generation will have to Grapple with portentous issues that your generation will', ' Mahendr says to embrace the ought not the is shape the world as it ought', ' Mahendra was founded by Two Brothers around the time of Independence it was a time', ' In the early 90s India and Indian industry were both in crisis faced with the prospect', ' He Future kind of situation where once again we had to prove that we as an Indian', ' Between 2002 and 2013 our profits went up 33 times our stock price went up 72 times', " Fletcher says it's important to accept that purpose can evolve and it can transform . He", " Taxi driver said everyone's problems are like laundry hanging out to dry in an open field", " I ask you why can't t
# ...

# %%
from summa.summarizer import summarize

# %%
text = str(text1)

# %%
print(text)
# Out:
# [" If everyone's problems were like laundry hanging out to dry in an open field and you", ' The world as we see it today we are wrestling with climate change pandemics terrorism', ' Through the metaverse we can live not just a virtual second life but also a parallel', ' Your generation will have to Grapple with portentous issues that your generation will', ' Mahendr says to embrace the ought not the is shape the world as it ought', ' Mahendra was founded by Two Brothers around the time of Independence it was a time', ' In the early 90s India and Indian industry were both in crisis faced with the prospect', ' He Future kind of situation where once again we had to prove that we as an Indian', ' Between 2002 and 2013 our profits went up 33 times our stock price went up 72 times', " Fletcher says it's important to accept that purpose can evolve and it can transform . He", " Taxi driver said everyone's problems are like laundry hanging out to dry in an open field", " I ask you why can't t
# ...

# %%
summarize(text, ratio = 0.5)
# Out:
# 'He", " Taxi driver said everyone\'s problems are like laundry hanging out to dry in an open field", " I ask you why can\'t the next individual who brings the is closer to the ought", \' The Harvard graduate has been away from his family and home for 4 years as an undergraduate\', \' Subscribe to our Weekly Newsletter for the latest updates in the weekly Newsquiz .'

# %%
# !pip install googletrans==3.1.0a0

# %%
from googletrans import Translator
translator = Translator()
out = translator.translate(text, dest='Bengali')
print(out)
# Out:
# Translated(src=en, dest=bn, text=["যদি প্রত্যেকের সমস্যাগুলি একটি খোলা মাঠে শুকানোর জন্য লন্ড্রি ঝুলিয়ে রাখার মতো হত এবং আপনি", 'বিশ্ব যেভাবে আমরা দেখছি আজ আমরা জলবায়ু পরিবর্তনের মহামারী সন্ত্রাসবাদের সাথে লড়াই করছি', 'মেটাভার্সের মাধ্যমে আমরা কেবল একটি ভার্চুয়াল সেকেন্ডে বাঁচতে পারি না জীবন কিন্তু একটি সমান্তরালও', 'আপনার প্রজন্মকে সূক্ষ্ম বিষয়গুলির সাথে লড়াই করতে হবে যা আপনার প্রজন্ম করবে', 'মহেন্দ্র বলেছেন আলিঙ্গন করার জন্য যা উচিত নয় বিশ্বের আকার ধারণ করা উচিত', 'মহেন্দ্র চারপাশে দুই ভাই দ্বারা প্রতিষ্ঠিত হয়েছিল স্বাধীনতার সময়টা ছিল একটা সময়', '৯০-এর দশকের গোড়ার দিকে ভারত এবং ভারতীয় শিল্প উভয়ই সম্ভাবনার মুখোমুখি হয়েছিল', 'সেই ভবিষ্যৎ ধরনের পরিস্থিতি যেখানে আবারও আমাদের প্রমাণ করতে হয়েছিল যে আমরা একজন ভারতীয় হিসেবে', 'এর মধ্যে 2002 এবং 2013 আমাদের মুনাফা 33 গুণ বেড়েছে আমাদের স্টকের দাম 72 গুণ বেড়েছে', "ফ্লেচার বলেছেন যে উদ্দেশ্যটি বিকশিত হতে পারে এবং এটি রূপান্তরিত হতে পারে তা মেনে নেওয়া গুরুত্বপূর্ণ। একটি খোলা মাঠে", "আমি আপনাকে জিজ্ঞাসা করি কেন পরবর্তী ব্যক্তি
# ...

# %%
from googletrans import Translator
translator = Translator()
out = translator.translate(text, dest='ka')
print(out.text)
# Out:
# ["ყველას პრობლემები რომ ჰგავდეს სარეცხს გაშრობად ღია მინდორში და შენ", "სამყარო, როგორც ჩვენ ვხედავთ მას დღეს, ჩვენ ებრძვით კლიმატის ცვლილების პანდემიის ტერორიზმს", "მეტავერსიის მეშვეობით ჩვენ შეგვიძლია ვიცხოვროთ არა მხოლოდ ვირტუალური წამით". ცხოვრება, არამედ პარალელიც“, „თქვენს თაობას მოუწევს შეებრძოლოს რთულ საკითხებს, რაც თქვენს თაობას მოუწევს“, - მაჰენდრი ამბობს, რომ აითვისოს ის, რაც არ უნდა იყოს, აყალიბებს სამყაროს ისე, როგორც უნდა, „მაჰენდრა დაარსდა ორი ძმის მიერ. დამოუკიდებლობის დრო ეს იყო დრო", "90-იანი წლების დასაწყისში ინდოეთი და ინდოეთის ინდუსტრია ორივე კრიზისში იმყოფებოდნენ პერსპექტივის წინაშე", "მას მომავალი ისეთი სიტუაცია, სადაც კიდევ ერთხელ უნდა დაგვემტკიცებინა, რომ ჩვენ, როგორც ინდოელებს", " შორის 2002 და 2013 წლებში ჩვენი მოგება 33-ჯერ გაიზარდა ჩვენი აქციების ფასი 72-ჯერ. ” ფლეტჩერი ამბობს, რომ მნიშვნელოვანია იმის აღიარება, რომ მიზანი შეიძლება განვითარდეს და ის გარდაიქმნას. ღია ველზე", "მე გეკითხები, რატომ არ შეიძლება შემდეგი ადამიანი, რომელიც მოაქვს საჭიროს", "ჰარვარ
# ...

# %%
from googletrans import Translator
translator = Translator()
out = translator.translate(text, dest='hi')
print(out.text)
# Out:
# ["अगर हर किसी की समस्याएँ खुले मैदान में सूखने के लिए लटके कपड़ों की तरह होतीं और आप", 'आज हम जिस दुनिया को देखते हैं हम जलवायु परिवर्तन महामारी आतंकवाद से जूझ रहे हैं', 'मेटावर्स के माध्यम से हम सिर्फ एक आभासी पल नहीं जी सकते हैं' जीवन लेकिन एक समानांतर भी', 'आपकी पीढ़ी को उन अप्रत्याशित मुद्दों से जूझना होगा जो आपकी पीढ़ी को झेलना पड़ेगा', 'महेंद्र कहते हैं कि जो चाहिए उसे अपनाओ, दुनिया को वैसा आकार दो जैसा उसे बनाना चाहिए', 'महेंद्र की स्थापना दो भाइयों ने की थी' आजादी के समय यह एक ऐसा समय था', '90 के दशक की शुरुआत में भारत और भारतीय उद्योग दोनों ही संभावनाओं के सामने संकट में थे', 'भविष्य की स्थिति ऐसी थी जहां एक बार फिर हमें यह साबित करना था कि हम एक भारतीय हैं', 'के बीच 2002 और 2013 में हमारा मुनाफा 33 गुना बढ़ गया, हमारे स्टॉक की कीमत 72 गुना बढ़ गई', फ्लेचर का कहना है कि यह स्वीकार करना महत्वपूर्ण है कि उद्देश्य विकसित हो सकता है और यह रूपांतरित हो सकता है। उन्होंने', 'टैक्सी ड्राइवर ने कहा कि हर किसी की समस्याएं सूखने के लिए लटके हुए कपड़ों की तरह हैं' एक खुले मैदान में", "म
# ...
